# %% [markdown]
# <a href="https://colab.research.google.com/github/AaryanAnand10/Implant/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Mount Google Drive if not already mounted
from google.colab import drive
drive.mount('/content/drive')

# Path to the knee implant folder
base_path = "/content/drive/MyDrive/Knee"

# List all implant types from folder names
implant_types = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]
print(f"Found {len(implant_types)} implant types:")
for i, implant in enumerate(implant_types):
    print(f"{i+1}. {implant}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 37 implant types:
# 1. Zimmer persona
# 2. Stryker SCORPIO
# 3. Zimmer Vanguard
# 4. TTK Healthcare BUCHEL PAPPAS
# 5. Zimmer biomet LCCK
# 6. Stryker TRIATHLON
# 7. Zimmer  LPS Flex Knee GSF
# 8. Zimmer UKS (ZUK)
# 9. Zimmer  INSALL BURSTEINI
# 10. Zimmer Oxford
# 11. Smith and Nephew  JOURNEY
# 12. Smith and Nephew ANTHEM
# 13. Smith and Nephew GENESIS II
# 14. Smith and Nephew  LEGION
# 15. Meril life FREEDOM KNEE
# 16. Smith and Nephew TC PLUS SOLUTION
# 17. Microport MEDIAPIVOT
# 18. Stryker NRG
# 19. Smith and Nephew Gensis PS
# 20. Link Gemini SL
# 21. Exatech Opterak Logic
# 22. Depuy PFC SIGMA
# 23. INTERMEDICS Natural Knee
# 24. Kyocera TRIBRID
# 25. Kyocera INITIA PS
# 26. Depuy LCS
# 27. Kyocera ACTIYAS
# 28. DJO 3D Knee
# 29. Howmedica DURACON TS
# 30. link endomodel
# 31. Anika unicap
# 32. Depuy Attune
# 33. Depuy COORDINATE
# 34. BIOIMPIANTI K mod
# 35. Depuy AMK
# 36. Biomet AGC
# 37. Aesculap Columbus

# %%
# Count images in each folder
image_counts = {}
total_images = 0

for implant in implant_types:
    folder_path = os.path.join(base_path, implant)
    image_files = [f for f in os.listdir(folder_path)
                  if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    image_counts[implant] = len(image_files)
    total_images += len(image_files)

# Display distribution
print(f"Total images: {total_images}")
for implant, count in image_counts.items():
    print(f"{implant}: {count} images ({count/total_images*100:.1f}%)")

# Check for class imbalance
plt.figure(figsize=(15, 6))
plt.bar(image_counts.keys(), image_counts.values())
plt.xticks(rotation=90)
plt.title("Number of Images per Implant Type")
plt.tight_layout()
plt.show()
# Out:
# Total images: 1500
# Zimmer persona: 58 images (3.9%)
# Stryker SCORPIO: 13 images (0.9%)
# Zimmer Vanguard: 58 images (3.9%)
# TTK Healthcare BUCHEL PAPPAS: 32 images (2.1%)
# Zimmer biomet LCCK: 12 images (0.8%)
# Stryker TRIATHLON: 51 images (3.4%)
# Zimmer  LPS Flex Knee GSF: 73 images (4.9%)
# Zimmer UKS (ZUK): 68 images (4.5%)
# Zimmer  INSALL BURSTEINI: 40 images (2.7%)
# Zimmer Oxford: 73 images (4.9%)
# Smith and Nephew  JOURNEY: 24 images (1.6%)
# Smith and Nephew ANTHEM: 48 images (3.2%)
# Smith and Nephew GENESIS II: 44 images (2.9%)
# Smith and Nephew  LEGION: 52 images (3.5%)
# Meril life FREEDOM KNEE: 60 images (4.0%)
# Smith and Nephew TC PLUS SOLUTION: 13 images (0.9%)
# Microport MEDIAPIVOT: 101 images (6.7%)
# Stryker NRG: 68 images (4.5%)
# Smith and Nephew Gensis PS: 48 images (3.2%)
# Link Gemini SL: 66 images (4.4%)
# Exatech Opterak Logic: 0 images (0.0%)
# Depuy PFC SIGMA: 41 images (2.7%)
# INTERMEDICS Natural Knee: 15 images (1.0%)
# Kyocera TRIBRID: 12 images (0.8%)
# Kyocera INITIA PS: 18 images (1.2%)
# Depuy LCS: 22 images (1.5%)
# Kyocera ACTIYAS　: 42 images (2.8%)
# DJO 3D Knee: 99 images (6.6%)
# Howmedica DURACON TS: 20 images (1.3%)
# link endomodel: 12 images (0.8%)
# Anika unicap: 10 images (0.7%)
# Depuy Attune: 52 images (3.5%)
# Depuy COORDINATE: 10 images (0.7%)
# BIOIMPIANTI K mod: 80 images (5.3%)
# Depuy AMK: 14 images (0.9%)
# Biomet AGC: 39 images (2.6%)
# Aesculap Columbus: 12 images (0.8%)
# <ipython-input-2-9d4efdb7eb3f>:22: UserWarning: Glyph 12288 (\N{IDEOGRAPHIC SPACE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12288 (\N{IDEOGRAPHIC SPACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Split ratios
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# Set up image generators with augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=validation_ratio + test_ratio
)

# Set up validation and test generators (just rescaling)
valid_test_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=validation_ratio/(validation_ratio + test_ratio)
)

# Image size - using 224x224 which is standard for many pre-trained models
img_height, img_width = 224, 224
batch_size = 16

# Create the generators
train_generator = train_datagen.flow_from_directory(
    base_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = valid_test_datagen.flow_from_directory(
    base_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=False
)

test_generator = valid_test_datagen.flow_from_directory(
    base_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Get class indices mapping
class_indices = train_generator.class_indices
idx_to_class = {v: k for k, v in class_indices.items()}

# Save class indices for later use
import json
with open('knee_implant_classes.json', 'w') as f:
    json.dump(idx_to_class, f)
# Out:
# Found 1121 images belonging to 37 classes.
# Found 794 images belonging to 37 classes.
# Found 784 images belonging to 37 classes.

# %%
# Create a base model from EfficientNetB3
base_model = EfficientNetB3(
    weights='imagenet',
    include_top=False,
    input_shape=(img_height, img_width, 3)
)

# Freeze the base model layers
base_model.trainable = False

# Create the model architecture
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(len(implant_types), activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print the model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)          │ (None, 7, 7, 1536)          │      10,783,535 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1536)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         786,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 37)                  │           9,509 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,711,316 (44.68 MB)
#  Trainable params: 927,781 (3.54 MB)
#  Non-trainable params: 10,783,535 (41.14 MB)

# %%
# Compute class weights if there's significant class imbalance
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
# Set up callbacks for better training
callbacks = [
    EarlyStopping(patience=7, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.2, patience=3, min_lr=1e-6),
    ModelCheckpoint('knee_implant_model_best.h5', save_best_only=True)
]

# Training
epochs = 20
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    class_weight=class_weight_dict,  # Add class weights to handle imbalance
    callbacks=callbacks
)

# Save the final model
model.save('knee_implant_model_final.h5')

# Plot the training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.0221 - loss: 3.7483
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 723s 10s/step - accuracy: 0.0221 - loss: 3.7485 - val_accuracy: 0.0076 - val_loss: 3.6170 - learning_rate: 0.0010
# Epoch 2/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.0245 - loss: 3.5712
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 35s 493ms/step - accuracy: 0.0246 - loss: 3.5724 - val_accuracy: 0.0151 - val_loss: 3.6072 - learning_rate: 0.0010
# Epoch 3/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 42s 508ms/step - accuracy: 0.0227 - loss: 3.6328 - val_accuracy: 0.0466 - val_loss: 3.6119 - learning_rate: 0.0010
# Epoch 4/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 39s 486ms/step - accuracy: 0.0389 - loss: 3.6532 - val_accuracy: 0.0466 - val_loss: 3.6127 - learning_rate: 0.0010
# Epoch 5/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 35s 493ms/step - accuracy: 0.0251 - loss: 3.6576 - val_accuracy: 0.0202 - val_loss: 3.6122 - learning_rate: 0.0010
# Epoch 6/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 35s 503ms/step - accuracy: 0.0152 - loss: 3.4551 - val_accuracy: 0.0202 - val_loss: 3.6119 - learning_rate: 2.0000e-04
# Epoch 7/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 34s 484ms/step - accuracy: 0.0178 - loss: 3.6460 - val_accuracy: 0.0252 - val_loss: 3.6121 - learning_rate: 2.0000e-04
# Epoch 8/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 34s 478ms/step - accuracy: 0.0237 - loss: 3.6339 - val_accuracy: 0.0252 - val_loss: 3.6121 - learning_rate: 2.0000e-04
# Epoch 9/20
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 33s 462ms/step - accuracy: 0.0310 - loss: 3.7383 - val_accuracy: 0.0252 - val_loss: 3.6120 - learning_rate: 4.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc:.4f}')

# Calculate and visualize the confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Get predictions
test_generator.reset()
y_pred = model.predict(test_generator, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

# Print classification report
class_names = list(idx_to_class.values())
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(16, 14))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 250s 5s/step - accuracy: 0.0106 - loss: 3.6066
# Test accuracy: 0.0153
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step
#                                    precision    recall  f1-score   support
#
#                 Aesculap Columbus       0.00      0.00      0.00         6
#                      Anika unicap       0.00      0.00      0.00         5
#                 BIOIMPIANTI K mod       0.00      0.00      0.00        42
#                        Biomet AGC       0.00      0.00      0.00        19
#                       DJO 3D Knee       0.00      0.00      0.00        49
#                         Depuy AMK       0.00      0.00      0.00         7
#                      Depuy Attune       0.00      0.00      0.00        26
#                  Depuy COORDINATE       0.00      0.00      0.00         5
#                         Depuy LCS       0.00      0.00      0.00        11
#                   Depuy PFC SIGMA       0.00      0.00      0.00        20
#             Exatech Opterak Logic       0.00      0.00      0.00        37
#              Howmedica DURACON TS       0.00      0.00      0.00        10
#          INTERMEDICS Natural Knee       0.00      0.00      0.00         7
#                  Kyocera ACTIYAS　       0.00      0.00      0.00        21
#                 Kyocera INITIA PS       0.00      0.00      0.00         9
#                   Kyocera TRIBRID       0.00      0.00      0.00         6
#                    Link Gemini SL       0.00      0.00      0.00        33
#           Meril life FREEDOM KNEE       0.00      0.00      0.00        30
#              Microport MEDIAPIVOT       0.00      0.00      0.00        50
#         Smith and Nephew  JOURNEY       0.02      1.00      0.03        12
#          Smith and Nephew  LEGION       0.00      0.00      0.00        26
#           Smith and Nephew ANTHEM       0.00      0.00      0.00        24
#       Smith and Nephew GENESIS II       0.00      0.00      0.00        22
#        Smith and Nephew Gensis PS       0.00      0.00      0.00        24
# Smith and Nephew TC PLUS SOLUTION       0.00      0.00      0.00         6
#                       Stryker NRG       0.00      0.00      0.00        34
#                   Stryker SCORPIO       0.00      0.00      0.00         6
#                 Stryker TRIATHLON       0.00      0.00      0.00        25
#      TTK Healthcare BUCHEL PAPPAS       0.00      0.00      0.00        16
#          Zimmer  INSALL BURSTEINI       0.00      0.00      0.00        20
#         Zimmer  LPS Flex Knee GSF       0.00      0.00      0.00        36
#                     Zimmer Oxford       0.00      0.00      0.00        36
#                  Zimmer UKS (ZUK)       0.00      0.00      0.00        34
#                   Zimmer Vanguard       0.00      0.00      0.00        29
#                Zimmer biomet LCCK       0.00      0.00      0.00         6
#                    Zimmer persona       0.00      0.00      0.00        29
#                    link endomodel       0.00      0.00      0.00         6
#
#                          accuracy                           0.02       784
#                         macro avg       0.00      0.03      0.00       784
#                      weighted avg       0.00      0.02      0.00       784
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 12288 (\N{IDEOGRAPHIC SPACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# <ipython-input-7-e500d6480c22>:27: UserWarning: Glyph 12288 (\N{IDEOGRAPHIC SPACE}) missing from font(s) DejaVu Sans.
#   plt.savefig('confusion_matrix.png')
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12288 (\N{IDEOGRAPHIC SPACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
